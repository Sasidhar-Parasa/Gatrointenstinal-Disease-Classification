# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (4.1.1)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=dddec7d067021805f4d0c2b38facc158cc1707d822651580552f935ee761ca67
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import os
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.optim import Adam
from torch.autograd import Variable
import torchvision
import pathlib
import zipfile
import math
from torch import nn
import torch.optim as optim
from torchvision import datasets, transforms
import shutil
from efficientnet_pytorch import EfficientNet

if torch.cuda.is_available():
  torch.backends.cudnn.deterministic = True

# %%
print(torch.__version__)
# Out:
# 1.11.0+cu113

# %%
device = torch.device ("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount ('/content/gdrive')
# !unzip "/content/gdrive/MyDrive/ResearchInternship/Dataset/Augmented_1.zip" -d "/content/labeled-images"
# !unzip "/content/gdrive/MyDrive/ResearchInternship/Dataset/Augmented_2.zip" -d "/content/labeled-images"
# !unzip "/content/gdrive/MyDrive/ResearchInternship/Dataset/Augmented_3.zip" -d "/content/labeled-images"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5115559.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5116039.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5194025.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_53400.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5423794.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5451332.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5500410.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5511542.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_566745.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5673955.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5737662.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5751083.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5758522.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5863677.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5881734.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_5888615.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6025652.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_608877.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6162022.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_620844.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6258710.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6260983.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6280041.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6331764.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6339560.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6353653.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6376637.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6412018.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_641895.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6437828.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_651859.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6536803.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_656056.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6649178.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6730817.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6849700.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6859595.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_6866375.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7023833.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_704047.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7113921.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7128782.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7163077.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7173004.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7218625.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7224509.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7233103.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7245843.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_725111.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7346827.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7352500.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7401510.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7404213.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7468372.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7488238.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7504993.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7540554.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7567155.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7579750.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7626769.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7661952.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7680393.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7702431.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7708247.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7828992.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_785734.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7930936.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7949262.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_7970444.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_801986.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_80352.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8044940.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_805682.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8225317.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8300744.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8449387.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8450271.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8472047.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8531418.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8538078.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8548414.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8614249.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8656899.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8790795.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8834121.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_883965.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8875403.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8929402.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_8998858.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9007733.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9016383.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9166710.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9221214.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9235679.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9238271.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9302315.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9331818.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9431816.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9445666.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9467444.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9519995.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9558769.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9566759.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9627581.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9629681.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9754864.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9808266.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9817092.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9844427.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_3_9968947.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1130532.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1183317.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1214349.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1233467.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1325543.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1491279.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1492390.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1547315.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_157546.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1733825.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1809477.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1813297.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1851404.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1870126.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1887797.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_193264.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_1949401.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2028698.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2036814.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2041765.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2058581.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2154103.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2161196.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2177041.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2335795.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_234158.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2389714.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2431159.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2441445.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2444779.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2546141.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2577331.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2592941.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2602763.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2624622.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2639924.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2689486.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2690445.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2695948.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2739610.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2742426.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2746433.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2760637.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2845894.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_2850081.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_297360.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3046942.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3102614.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3110638.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3140822.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3149652.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3154025.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3228981.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3257587.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3318004.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3338872.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3353130.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3374503.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3404250.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3457542.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3472283.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3547631.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3589656.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3670150.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3734732.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3744872.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3773104.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3812364.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3947809.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3961616.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3961799.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_3975220.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4010125.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4047419.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4063386.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4084374.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4122326.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4183659.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4260455.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4283359.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4300477.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4338616.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4374696.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4586488.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4596567.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4674808.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4675781.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4718991.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_475437.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4783428.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4792441.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4803019.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_48530.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_4996988.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5037729.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5131810.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5186679.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5201085.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5269542.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5302944.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5338426.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5370494.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5569332.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5581064.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5636116.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5701202.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_580211.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5810149.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5869361.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5899163.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5956057.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_5990981.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6114892.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6133262.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6198558.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6203691.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6313088.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6427197.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6446295.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6477858.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6541216.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6611239.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6660330.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6708511.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6758550.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6823616.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6832756.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6877666.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_6931372.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7045423.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7090315.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7173042.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7202334.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7264155.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7310787.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7374780.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7395949.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7478154.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7498032.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7526110.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7546491.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7547808.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7550871.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7601329.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_760898.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_776972.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_778898.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7813737.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7832677.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7969044.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7980350.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_7989743.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8004591.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8011550.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8053283.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8056340.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8217566.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8260676.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8404501.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8419477.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8456418.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8586837.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8594558.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8595197.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8616800.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8625072.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8730020.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8754191.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8763120.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8783644.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_884641.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_8942554.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9022655.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9137613.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9154072.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9170444.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9202639.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9305014.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9349623.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9352136.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9359360.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9375831.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9432282.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9433618.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9448686.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9460072.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9535841.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9625420.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9699586.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_4_9713935.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1008914.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1021355.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1081019.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1125103.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1171036.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1172254.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1216548.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1297188.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1365541.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1376760.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1380488.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1403311.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1454822.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_14779.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1479319.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1508760.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1631947.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_167218.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1682438.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_171430.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1903818.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_1940446.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2000347.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2208073.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2257975.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2283158.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2333594.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2339234.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2357517.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2383364.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2427148.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2506073.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2640676.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2654613.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2709104.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2735340.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2735389.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2782335.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2831178.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2834948.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2934456.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_2951136.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3001647.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3029528.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3071672.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3126857.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_316473.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3234824.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3281781.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3289914.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3405330.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3410867.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3436844.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3539190.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3631008.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3665951.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_38489.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3852538.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3866690.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_388948.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3909406.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_3988319.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4009282.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4012139.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4121244.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4141102.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4269141.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4288915.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4326867.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4511007.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4601383.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4671016.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4754432.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4824778.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4914316.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_4949160.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_501110.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5121371.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5146208.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5196620.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5245025.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5310076.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5354306.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5378919.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5424507.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_54310.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5466113.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5471575.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5477821.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5502319.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5543723.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5560767.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5590120.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_566566.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5670093.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5720018.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5762086.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5826505.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5836668.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5840081.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5883314.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5891994.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5897694.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_5999552.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6077088.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6084209.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6175852.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6199664.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6202126.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6382398.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6463160.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6484176.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6515459.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6515523.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6530514.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_654241.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6555399.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6624780.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_66750.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6689249.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6721788.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6838049.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6883504.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_6885953.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7152588.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_721087.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7256811.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7294803.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7297859.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7300968.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7305173.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7347748.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7359266.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7372292.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7392659.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7430257.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7436298.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7440664.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7497890.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7586458.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7619651.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7637265.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7710215.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7754480.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7805794.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7836916.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7853218.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7885554.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7896468.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7899856.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_7967084.png
#   inflating: /content/labeled-images/Augmented_3/ulcerative-colitis-grade-1-2_augment/aug_5_8044681.png
# ...
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_808_4604950.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_809_1602453.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_81_915754.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_810_6933896.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_811_1697755.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_811_430169.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_812_4842461.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_812_9587753.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_813_8507911.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_814_1321611.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_815_7908534.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_816_4056586.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_817_3628711.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_818_8515889.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_819_32781.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_819_7864238.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_82_1143208.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_820_6282868.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_821_209710.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_821_5206409.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_822_5039674.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_822_8589983.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_823_2241024.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_823_4623416.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_824_8795162.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_825_8307186.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_826_2903722.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_826_3203345.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_827_2740648.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_828_4386996.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_829_9908029.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_83_721452.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_830_1771495.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_830_2499450.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_831_8720092.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_832_8402610.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_833_6822152.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_833_8295396.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_834_7313064.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_835_8198353.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_836_4264325.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_836_6116904.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_836_86839.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_837_3728990.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_837_853704.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_838_2202386.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_840_8903899.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_842_1209617.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_842_9634084.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_843_4933974.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_845_4344076.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_846_2006680.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_847_3785029.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_847_7422367.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_848_183200.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_849_5275056.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_849_6703728.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_85_7517462.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_850_6535113.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_851_9766585.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_852_9329955.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_853_1705162.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_854_611934.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_854_8510984.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_855_4307465.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_855_4855884.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_856_4460115.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_856_694043.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_856_8771755.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_857_468539.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_858_6977008.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_859_1848172.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_86_7304982.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_860_2271283.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_860_6938449.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_861_9412950.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_862_8405165.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_864_973425.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_865_1783539.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_866_1577267.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_866_2828177.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_867_7026068.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_868_1087485.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_869_8587846.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_87_1534557.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_870_1070970.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_870_7401146.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_871_5879700.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_872_3380071.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_873_181353.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_874_5215286.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_875_3026478.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_877_1629932.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_878_9345434.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_879_5260010.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_88_9636840.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_880_4388086.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_881_2331700.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_882_1094928.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_882_1662269.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_883_3682414.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_884_1925506.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_884_6862528.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_885_1232950.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_885_2788100.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_885_9059189.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_886_2729540.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_887_598614.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_887_8303657.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_888_2181389.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_889_5412000.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_89_3414392.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_89_9550584.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_890_9436348.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_891_4735586.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_891_722878.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_892_3782324.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_893_556314.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_894_1878781.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_894_7661162.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_895_6305014.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_895_999937.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_896_4873003.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_897_1336436.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_897_3824887.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_897_494925.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_898_1421724.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_898_343574.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_898_8898953.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_899_3318677.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_9_5673967.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_9_6026096.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_90_3758982.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_900_3512759.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_901_5764350.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_902_7932931.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_903_3437004.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_904_9777502.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_905_9821377.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_906_2428406.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_907_1193711.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_908_3476624.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_908_9739624.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_909_1858119.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_909_5050638.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_91_2457719.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_91_2513215.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_910_9448613.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_911_3786483.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_912_7021207.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_913_2789311.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_914_3409465.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_915_246221.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_915_4021981.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_915_6877738.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_916_5095405.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_917_3912700.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_918_9062123.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_919_1520332.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_919_7913674.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_92_434466.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_92_8344033.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_920_651964.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_922_2695776.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_922_5745306.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_923_8079621.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_924_8264577.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_924_9335580.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_925_6213024.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_926_5538403.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_927_208343.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_927_6200407.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_928_5094656.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_929_6848530.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_93_5071453.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_930_1397523.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_931_1589172.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_931_5949490.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_94_4432062.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_94_8456831.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_95_6039332.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_96_2544198.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_97_1899615.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_97_6196808.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_98_4470059.png
#   inflating: /content/labeled-images/Augmented_3/z-line_augment/aug_99_1434951.png

# %%
# !mkdir /content/dataset

# %%
cn1_path = "/content/labeled-images/Augmented_1/"
cn2_path = "/content/labeled-images/Augmented_2/"
cn3_path = "/content/labeled-images/Augmented_3/"
cn1 = ['barretts', 'barretts-short-segment', 'bbps-0-1', 'bbps-2-3', 'cecum', 'dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis-a'] 
cn2 = ['esophagitis-b-d', 'hemorrhoids', 'ileum', 'impacted-stool', 'polyps', 'pylorus', 'retroflex-rectum', 'retroflex-stomach']
cn3 = ['ulcerative-colitis-grade-0-1', 'ulcerative-colitis-grade-1', 'ulcerative-colitis-grade-1-2', 'ulcerative-colitis-grade-2', 'ulcerative-colitis-grade-2-3', 'ulcerative-colitis-grade-3', 'z-line']

for name in cn1:
  path = str(cn1_path + name + '_augment')
  shutil.move (path, "/content/dataset" )

for name in cn2:
  path = str(cn2_path + name + '_augment')
  shutil.move (path, "/content/dataset" )

for name in cn3:
  path = str(cn3_path + name + '_augment')
  shutil.move (path, "/content/dataset" )

# %%
# !rm -rf '/content/dataset/barretts-short-segment_augment/aug_0_2328103.png'
# !rm -rf '/content/dataset/barretts_augment/aug_0_211206.png'
# !rm -rf '/content/dataset/bbps-0-1_augment/aug_0_3938020.png'

# %%
#HYPERPARAMETERS

batch_size = 16
num_epochs = 5
num_classes = 23
LEARNING_RATE = 0.0001
WEIGHT_DECAY = 0.0001

# %%
transformer=transforms.Compose([
    #transforms.Resize((256,256)),
    transforms.Resize((50,50)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
])

# %%
dataset_path = '/content/dataset'

def load_dataset():
    train_dataset_manual = torchvision.datasets.ImageFolder(dataset_path, transform=transformer)
    train_loader_manual = torch.utils.data.DataLoader(train_dataset_manual)
    return train_loader_manual


full_dataset = load_dataset()


train_size = int(0.6 * len(full_dataset))
test_size = int (0.2 * len(full_dataset))
valid_size = len(full_dataset) - train_size - test_size


train_dataset, test_dataset, valid_dataset = torch.utils.data.random_split(full_dataset.dataset, [train_size, test_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=0, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=0, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=0, shuffle=True)

print('Full Dataset - ' + str(len(full_dataset)) + ' images.')
print('Train Set- ' + str(train_size) + ' images in ' + str(len(train_loader)) +' batches')
print('Testing Set - ' + str(test_size) + ' images in ' + str(len(test_loader)) + ' batches' )
print('Validation Set - ' + str(valid_size) + ' images in ' + str(len(valid_loader)) + ' batches')

train_count = train_size
test_count = test_size
valid_count = valid_size
# Out:
# Full Dataset - 25440 images.
# Train Set- 15264 images in 954 batches
# Testing Set - 5088 images in 318 batches
# Validation Set - 5088 images in 318 batches

# %%
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([16, 3, 50, 50])
# Image label dimensions: torch.Size([16])

# %%
root = pathlib.Path (dataset_path)
classes = sorted ([j.name.split('/')[-1] for j in root.iterdir()])
print (classes)
print(len(classes))
# Out:
# ['barretts-short-segment_augment', 'barretts_augment', 'bbps-0-1_augment', 'bbps-2-3_augment', 'cecum_augment', 'dyed-lifted-polyps_augment', 'dyed-resection-margins_augment', 'esophagitis-a_augment', 'esophagitis-b-d_augment', 'hemorrhoids_augment', 'ileum_augment', 'impacted-stool_augment', 'polyps_augment', 'pylorus_augment', 'retroflex-rectum_augment', 'retroflex-stomach_augment', 'ulcerative-colitis-grade-0-1_augment', 'ulcerative-colitis-grade-1-2_augment', 'ulcerative-colitis-grade-1_augment', 'ulcerative-colitis-grade-2-3_augment', 'ulcerative-colitis-grade-2_augment', 'ulcerative-colitis-grade-3_augment', 'z-line_augment']
# 23

# %%
class ASPP(nn.Module):
	def __init__(self, dim_in, dim_out, rate=1, bn_mom=0.1):
		super(ASPP, self).__init__()
		self.branch1 = nn.Sequential(
			nn.Conv2d(dim_in, dim_out, 1, 1, padding=0, dilation=rate, bias=True),
			nn.BatchNorm2d(dim_out),
			nn.ReLU(inplace=True),
		)
		self.branch2 = nn.Sequential(
			nn.Conv2d(dim_in, dim_out, 3, 1, padding=6 * rate, dilation=6 * rate, bias=True),
			nn.BatchNorm2d(dim_out),
			nn.ReLU(inplace=True),
		)
		self.branch3 = nn.Sequential(
			nn.Conv2d(dim_in, dim_out, 3, 1, padding=12 * rate, dilation=12 * rate, bias=True),
			nn.BatchNorm2d(dim_out),
			nn.ReLU(inplace=True),
		)
		self.branch4 = nn.Sequential(
			nn.Conv2d(dim_in, dim_out, 3, 1, padding=18 * rate, dilation=18 * rate, bias=True),
			nn.BatchNorm2d(dim_out),
			nn.ReLU(inplace=True),
		)
		self.branch5_conv = nn.Conv2d(dim_in, dim_out, 1, 1, 0, bias=True)
		self.branch5_bn = nn.BatchNorm2d(dim_out)
		self.branch5_relu = nn.ReLU(inplace=True)
		self.conv_cat = nn.Sequential(
			nn.Conv2d(dim_out * 5, dim_out, 1, 1, padding=0, bias=True),
			nn.BatchNorm2d(dim_out),
			nn.ReLU(inplace=True),
		)

	def forward(self, x):
		[b, c, row, col] = x.size()
		conv1x1 = self.branch1(x)
		conv3x3_1 = self.branch2(x)
		conv3x3_2 = self.branch3(x)
		conv3x3_3 = self.branch4(x)
		global_feature = torch.mean(x, 2, True)
		global_feature = torch.mean(global_feature, 3, True)
		global_feature = self.branch5_conv(global_feature)
		global_feature = self.branch5_bn(global_feature)
		global_feature = self.branch5_relu(global_feature)
		global_feature = F.interpolate(global_feature, (row, col), None, 'bilinear', True)

		feature_cat = torch.cat([conv1x1, conv3x3_1, conv3x3_2, conv3x3_3, global_feature], dim=1)
		result = self.conv_cat(feature_cat)
        
		return result

# %%
class FireModule (nn.Module):

    def __init__(self, inplanes, squeeze_planes, expand1x1_planes, expand3x3_planes):
        super(FireModule, self).__init__()
        self.inplanes = inplanes
        self.squeeze = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        self.squeeze_activation = nn.ReLU(inplace=True)
        self.expand1x1 = nn.Conv2d(squeeze_planes, expand1x1_planes, kernel_size=1)
        self.expand1x1_activation = nn.ReLU(inplace=True)
        self.expand3x3 = nn.Conv2d(squeeze_planes, expand3x3_planes, kernel_size=3, padding=1)
        self.expand3x3_activation = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.squeeze_activation(self.squeeze(x))
        return torch.cat([
            self.expand1x1_activation(self.expand1x1(x)),
            self.expand3x3_activation(self.expand3x3(x))
        ], 1)

# %%
class CustomBack (nn.Module):

    def __init__(self, os):
        super(CustomBack, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 96, kernel_size=7, stride=2)
        self.relu = nn.ReLU(inplace=True)
        self.mp1 = nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True)
        
        self.fb1 = FireModule(96, 16, 64, 64)

        self.fb2 = FireModule(128, 16, 64, 64)

        rate = 16//os

        self.layers = []



        #------- init weights --------
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        #-----------------------------

    def forward(self, input):
        self.layers = []
        x = self.conv1(input)
        x = self.relu(x)
        x = self.mp1(x)

        self.layers.append(x)
        
        x = self.fb1(x)
        self.layers.append(x)

        x = self.fb2(x)
        self.layers.append(x)

        return x

    def get_layers(self):
        return self.layers

# %%
class Gumbel(nn.Module):
    ''' 
    Returns differentiable discrete outputs. Applies a Gumbel-Softmax trick on every element of x. 
    '''
    def __init__(self):
        super(Gumbel, self).__init__()
        self.factor = 1.0
        self.gumbel_noise = True

    def forward(self, x):
        if not self.training:  # no Gumbel noise during inference
            return (x >= 0).float()

        if self.gumbel_noise:
            U = torch.rand_like(x)
            g= -torch.log( - torch.log(U + 1e-8) + 1e-8)
            x = x + g

        soft = torch.sigmoid(x / self.factor)
        hard = ((soft >= 0.5).float() - soft).detach() + soft
        assert not torch.any(torch.isnan(hard))
        
        return hard

class Binary_Gate_Unit(nn.Module):
    
    def __init__(self, in_channels = 1024,  k = 100):
        super(Binary_Gate_Unit, self).__init__()
        self.in_channels = in_channels
        self.k = k
        self.conv= nn.Sequential(
            nn.Conv2d(in_channels=self.in_channels, out_channels=1, kernel_size=1, stride=1, padding=0, bias = False),
            nn.ReLU(inplace=True)            
            )
        self.fc1 = nn.Linear(k, int(torch.ceil(torch.tensor(k/2))))
        self.fc2 = nn.Linear(int(torch.ceil(torch.tensor(k/2))), k)
        
        self.gumbel = Gumbel()

    def forward(self,topk_prototypes):
        
        b = topk_prototypes.size(0)
        proto_weights = self.conv(topk_prototypes) # meta learner
        proto_weights = proto_weights.view(b, -1)
        proto_weights = self.fc1(torch.relu(proto_weights)) 
        proto_weights = self.fc2(proto_weights) # b, k
        proto_weights = self.gumbel(proto_weights)      
        proto_weights = proto_weights.view(b, 1, self.k, 1)
        
        return proto_weights


class Lesion_Location_Mining(nn.Module):

    def __init__(self, in_channels = 1024,  k = 100):
        super(Lesion_Location_Mining, self).__init__()
        self.k = k       
        self.BGU_fore =Binary_Gate_Unit(in_channels = in_channels,  k = k)
        self.BGU_back =Binary_Gate_Unit(in_channels = in_channels,  k = k)
        
    def forward(self, feats, soft_mask):
        
        b,c,h,w = feats.size()
        hard_mask = torch.max(soft_mask, dim = 1, keepdim = True)[1] # b, 1, h, w
        background_hard_mask = (hard_mask == 0).float()          
        foreground_hard_mask = (hard_mask == 1).float()
        assert torch.sum(hard_mask == 2) == 0, 'Error in Lesion_Location_Mining_Module'
        background_soft_mask, foreground_soft_mask = soft_mask.split(1, dim = 1)    #b, 1, h, w
        foreground_feats = feats * foreground_hard_mask # b, c, h, w
        background_feats = feats * background_hard_mask # b, c, h, w    
        feats = feats.view(b, c, -1) # b, c, hw        
        
        #****** foreground-->background **********#
        #key generator
        foreground_soft_mask = foreground_soft_mask.view(b, 1, -1)
        topk_idx = torch.topk(foreground_soft_mask, self.k, dim = -1, largest=True)[1]     
        topk_prototypes = []
        for i in range(b):
            feats_temp = feats[i,:,topk_idx[i]] # c, k
            topk_prototypes.append(feats_temp)
        topk_prototypes = torch.stack(topk_prototypes) # b, c, k
        topk_prototypes = topk_prototypes.view(b, c, self.k, 1)                
        proto_weights = self.BGU_fore(topk_prototypes) 
        topk_prototypes = topk_prototypes * proto_weights # b, c, k, 1         
               
        # b, c, h, w # b, c, k ---> 
        background_feats = background_feats.view(b, c, -1) # b, c, hw
        topk_prototypes = topk_prototypes.view(b, c, -1).permute(0, 2, 1) # b, k, c 
        fore_attention_map = torch.matmul(topk_prototypes, background_feats) # b, k ,hw
       
        #norm + relu
        norm_prototypes = torch.norm(topk_prototypes, dim = -1, keepdim=True) # b, k, 1
        norm_background_feats = torch.norm(background_feats, dim = 1, keepdim=True) #b, 1, hw
        norm = torch.bmm(norm_prototypes, norm_background_feats) # b, k, hw
        fore_attention_map =  fore_attention_map /(norm + 1e-8)
        fore_attention_map = torch.relu(fore_attention_map)
        fore_attention_map = fore_attention_map.view(b, self.k, h, w) 
        fore_attention_map = torch.max(fore_attention_map, dim = 1,  keepdim = True) [0]

        #****** background-->foreground**********#
        #key generator
        background_soft_mask = background_soft_mask.view(b, 1, -1)
        topk_idx = torch.topk(background_soft_mask, self.k, dim = -1, largest=True)[1]                 
        topk_prototypes = []
        for i in range(b):
            feats_temp = feats[i,:,topk_idx[i]] # c, k
            topk_prototypes.append(feats_temp)
        topk_prototypes = torch.stack(topk_prototypes) # b, c, k
        topk_prototypes = topk_prototypes.view(b, c, self.k, 1)        
        proto_weights = self.BGU_back(topk_prototypes) 
        topk_prototypes = topk_prototypes * proto_weights # b, c, k, 1
               
        # b, c, h, w # b, c, k ---> 
        foreground_feats = foreground_feats.view(b, c, -1) # b, c, hw
        topk_prototypes = topk_prototypes.view(b, c, -1).permute(0, 2, 1) # b, k, c
        back_attention_map = torch.matmul(topk_prototypes, foreground_feats) # b, k ,hw
        #norm + relu
        norm_prototypes = torch.norm(topk_prototypes, dim = -1, keepdim=True) # b, k, 1
        norm_foreground_feats = torch.norm(foreground_feats, dim = 1, keepdim=True) #b, 1, hw
        norm = torch.bmm(norm_prototypes, norm_foreground_feats) # b, k, hw
        back_attention_map =  back_attention_map /(norm + 1e-8)
        back_attention_map = torch.relu(back_attention_map)
        back_attention_map = back_attention_map.view(b, self.k, h, w) 
        back_attention_map = torch.max(back_attention_map, dim = 1,  keepdim = True) [0]
     
        #merging
        feats = feats.view(b, c, h, w)
        foreground_soft_mask = foreground_soft_mask.view(b, 1, h, w)
        feats = feats + feats * (foreground_soft_mask - back_attention_map + fore_attention_map)
        
        return feats  #b, c, h,w

# %%
"""
Applies the mish function element-wise:
mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + exp(x)))
"""
class Mish(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input):
        if torch.__version__ >= "1.9":
            return F.mish(input)
        else:
            return mish(input)

def mish(input):
    return input * torch.tanh(F.softplus(input))

# %%
class GI_Model(nn.Module):
    def __init__(self, K=100):
        super(GI_Model, self).__init__()
        self.backbone = None
        self.backbone_layers = None
        self.dropout = nn.Dropout(0.5)
        #self.upsample_sub_x2 = nn.UpsamplingBilinear2d(scale_factor=2) 
        #self.upsample_sub_x4 = nn.UpsamplingBilinear2d(scale_factor=4)         
        #self.shortcut_conv = nn.Sequential(nn.Conv2d(128, 48, 1, 1, padding=1//2, bias=True),
        self.shortcut_conv = nn.Sequential(nn.Conv2d(96, 48, 1, 1, padding=1//2, bias=True),
				nn.BatchNorm2d(48),
				nn.ReLU(inplace=True),
		)
        self.aspp = ASPP(dim_in=128, dim_out=128, rate=16//16, bn_mom = 0.99)

        self.coarse_head = nn.Sequential(
				nn.Conv2d(128+48, 128, 3, 1, padding=1, bias=True),
        #nn.Conv2d(128, 128, 3, 1, padding=1, bias=True),
				nn.BatchNorm2d(128),
				nn.ReLU(inplace=True),
				nn.Dropout(0.5),
				nn.Conv2d(128, 128, 3, 1, padding=1, bias=True),
				nn.BatchNorm2d(128),
				nn.ReLU(inplace=True),
				nn.Dropout(0.1),
                nn.Conv2d(128, 2, kernel_size=1, stride=1, padding=0, bias=True)
		)

        self.cls_head = nn.Sequential (
          #nn.Conv2d(128, 256, kernel_size=3, stride=1),
          nn.Conv2d(128, 256, kernel_size=1, stride=1),
          nn.BatchNorm2d(256),
			    Mish(),
       
          #nn.Conv2d(256, 512, kernel_size=3, stride=1),
          nn.Conv2d(256, 512, kernel_size=1, stride=1),
          nn.BatchNorm2d(512),
			    Mish(),
       
          #nn.Conv2d(512, 1024, kernel_size=3, stride=1),
          nn.Conv2d(512, 1024, kernel_size=1, stride=1),
          nn.BatchNorm2d(1024),
			    Mish()
        
    )

        self.LLM = Lesion_Location_Mining(128, 10)       
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.avgpool5 = nn.AdaptiveAvgPool2d(5)

        self.cls_predict = nn.Linear(1024, num_classes, bias = False)       
                       
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

        self.backbone = CustomBack(8)
        self.backbone_layers = self.backbone.get_layers()

        self.checker = nn.Conv2d(50, 128, kernel_size=3, stride=1)


    def forward(self, x):

      #CUSTOM BACKBONE LAYER
        x = self.backbone(x)
        
        
        layers = self.backbone.get_layers()                 #shllow feature
        feature_shallow = self.shortcut_conv(layers[0])    
        feature_aspp = self.aspp(layers[-1])            
        feature_coarse= self.dropout(feature_aspp)          #coarse seg   
        #feature_coarse = self.upsample_sub_x2(feature_coarse)

        #Added
        #print('feature coarse')
        #print(feature_coarse.shape)

        feature_coarse = self.avgpool5(feature_coarse)
        feature_shallow = self.avgpool5 (feature_shallow)

        #

        feature_coarse = torch.cat([feature_coarse,feature_shallow],1)
        seg_coarse = self.coarse_head(feature_coarse)              
        cls_feats = layers[-2]                              #####cls

        #Added
        #print('cls feats')
        #print(cls_feats.shape)

        cls_feats = self.avgpool5(cls_feats)

        #x = self.checker(cls_feats)
        # 

        b, c, h, w = cls_feats.size()
        mask_coarse = torch.softmax(seg_coarse, dim = 1)       
        mask_coarse = F.interpolate(mask_coarse, size=(h, w), mode="bilinear", align_corners=False)
        #CHANGE HERE
        
        cls_feats = self.LLM(feats = cls_feats, soft_mask =  mask_coarse)      
                
        
        cls_feats = self.cls_head(cls_feats)                     
        cls_out = self.avgpool(cls_feats)

        cls_out = cls_out.view(b, -1) 

        #print ('cls_out', cls_out.shape)
        cls_out = self.cls_predict(cls_out)     

        return cls_out

# %%
class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB

        #self.modelA.cls_predict = nn.Identity()
        #self.modelB._fc = nn.Identity()

        #From S102
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.ad = nn.AlphaDropout(0.5)
        self.r = nn.ReLU(inplace = True)

        self.classifier = nn.Linear(in_features = 1023, out_features = num_classes)

        
    def forward(self, x):
        x1 = self.modelA(x.clone())
        #x1 = x1.view(x1.size(0), -1)

        #print('x1_shape:',x1.shape)

        x2 = self.modelB(x)
        #x2 = x2.view(x2.size(0), -1)

        #print('x2_shape:',x2.shape)

        x = torch.cat((x1, x2), dim=1)

        #print('x_cat:',x.shape)

        #x = self.gap(x)

        #print('x_cat:',x.shape)

        x = self.ad(x)

        #print('x_cat:',x.shape)

        x = self.r(x)
        
        

        x = self.classifier(x)
        return x

# %%
PATHa = '/content/gdrive/MyDrive/ResearchInternship/Saves/CustomModel_50epochs'
PATHb = '/content/gdrive/MyDrive/ResearchInternship/Saves/EfficientNetBo_50_Epochs'

#Load Models
modelA = GI_Model().to(device) 
modelB = EfficientNet.from_pretrained('efficientnet-b0').to(device)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
# Load state dicts
modelA.load_state_dict(torch.load(PATHa))
# Out:
# <All keys matched successfully>

# %%
modelB.load_state_dict(torch.load(PATHb))
# Out:
# <All keys matched successfully>

# %%
model_new = MyEnsemble(modelA, modelB).to(device)

# %%
state_dict = torch.load('/content/Ensemble_95Epoch')

# %%
model_new.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
optimizer=Adam(model_new.parameters(),lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)
loss_function=nn.CrossEntropyLoss()

# %%
for epoch in range(num_epochs):
    
    #Evaluation and training on training dataset
    model_new.train()

    train_accuracy=0.0
    train_loss=0.0
    
    for i, (images,labels) in enumerate(train_loader):
        #print (i)
        if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())
            
        optimizer.zero_grad()
        
        outputs=model_new(images)
        
        loss=loss_function(outputs,labels)
        loss.backward()
        optimizer.step()
        
        
        #train_loss+= loss.cpu().data*images.size(0)
        train_loss += loss.item()
        _,prediction=torch.max(outputs.data,1)
        
        train_accuracy+=int(torch.sum(prediction==labels.data))
        
    train_accuracy=train_accuracy/train_count
    train_loss=train_loss/train_count
    
    
    # Evaluation on testing dataset
    model_new.eval()
    
    valid_accuracy = 0.0
    valid_loss = 0.0

    for i, (images,labels) in enumerate(valid_loader):
        if torch.cuda.is_available():
          images=Variable(images.cuda())
          labels=Variable(labels.cuda())
            
        outputs=model_new(images)

        loss = loss_function (outputs, labels)
        _,prediction=torch.max(outputs.data,1)
        valid_accuracy += int(torch.sum(prediction == labels.data))
        #test_accuracy+=int(torch.sum(prediction==labels.data))
        valid_loss+= loss.item()
        
    #test_accuracy=test_accuracy/test_count
    valid_accuracy = valid_accuracy/test_count
    valid_loss = valid_loss/test_count
        
        
    print('Epoch: %d Train Loss: %.5f Train Accuracy: %.5f Validation Loss: %.5f  Validation Accuracy: %.5f' % (epoch, train_loss, train_accuracy, valid_loss, valid_accuracy))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Epoch: 0 Train Loss: 0.00456 Train Accuracy: 0.97497 Validation Loss: 0.00932  Validation Accuracy: 0.95460
# Epoch: 1 Train Loss: 0.00455 Train Accuracy: 0.97478 Validation Loss: 0.01213  Validation Accuracy: 0.94261
# Epoch: 2 Train Loss: 0.00444 Train Accuracy: 0.97556 Validation Loss: 0.01041  Validation Accuracy: 0.94969
# Epoch: 3 Train Loss: 0.00444 Train Accuracy: 0.97838 Validation Loss: 0.01048  Validation Accuracy: 0.94772
# Epoch: 4 Train Loss: 0.00393 Train Accuracy: 0.98035 Validation Loss: 0.01036  Validation Accuracy: 0.95067

# %%
    torch.save(model_new.state_dict(),'/content/Ensemble_100Epoch')
